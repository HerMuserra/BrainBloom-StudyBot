# %%
# BrainBloom Study Buddy - Starter

# Sample notes
notes = {
    "AI": "Artificial Intelligence is the simulation of human intelligence in machines.",
    "Machine Learning": "Machine Learning is a subset of AI where machines learn from data.",
    "Python": "Python is a versatile programming language used for AI, web dev, and more."
}

def ask_bot(topic):
    return notes.get(topic, "Hmm… I don't know about that. Try another topic!")

# Example interaction
topic = input("Ask me about a topic: ")
print(ask_bot(topic))
# Out:
# Ask me about a topic: AI
# Artificial Intelligence is the simulation of human intelligence in machines.
